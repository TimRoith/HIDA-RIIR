# %% [markdown]
# # Part III: Data Driven Approaches
#
# In this tutorial, we want to explore some data driven methods for image reconstruction. We will consider the limited angle CT problem with additional noise on the sinogram. Our test data will be composed of simple shapes which can be loaded from the utils module. Namely, the shapes are created via random weighted norm balls in $\ell^p$ norms, i.e., we consider sets
#
# $$ \left\{x\in\mathbb{R}^2: \left(\sum_{i=1}^2 w_i |x_i - m_i|^p\right)^{1/p} < r\right\} $$
#
# where $r>0, w\in\mathbb{R}^2, m\in\mathbb{R}^2$ are sampled randomly.
#
# Let's look at the shapes this produces.

# %%
import matplotlib.pyplot as plt
from utils import random_weighted_norm

img_size = 64 #image size
rwn = random_weighted_norm(img_size=img_size)

# plot all shapes
P = 5
fig, ax = plt.subplots(1, P, figsize=(20,15))
for i in range(P):
    ax[i].imshow(rwn(p=2**i))
    ax[i].set_title('p=' + str(2**i))

# %% [markdown]
# # How does our data look like?
# Our data is given as the naive recon of a limited angle CT problem. The next cell defines the function that samples a batch of the data. The second output of the function ```get_data``` is the original input (ground truth) that will be used for the supervised learning scheme.
#
# The original image is returned as a  ```torch``` tensor, since this is more convenient for the training later. Furthermore, inputs and outputs into the net will have the shape
#
# $$
# B \times C \times N\times N
# $$
#
# where
#
# * $B$ denotes the batch size,
# * $C$ the number of channels (we always use $C=1$),
# * $N$ the image dimension.
#
# We have to be careful when we compare ```numpy``` and ```torch``` objects in the following. If we want to plot a ```torch``` Tensor ```x```, the following steps might be necessary:
#
# * ```x.detach()```: if the tensor ```x``` has a gradient, then we need to detach it first.
# * ```x.numpy()```: this converts a ```torch``` tensor, without a gradient, to a ```numpy``` array. Commands like ```plt.imshow``` do this internally.
# * ```x[b,c,...]```: ```plt.imshow``` only works for 2D arrays, so we have to select one batch element $b$ and a channel $c$.
#
# We now define a routine that returns our data. Basically, we sample a shape $x$ and then also return
#
# $$R^{-1}(R(x) + \delta)$$
#
# as the input to the net, where $R$ is the Radon transform with limited angles ($0^\circ$ to $90^\circ$), and $\delta$ denotes noise. Here, $R^{-1}$ is not the true inverse, but the naive Radon inversion.

# %%
import torch
import numpy as np
from operators import Radon
from itertools import cycle

num_thetas = 10
min_angle = 0
max_angle = 90
theta = np.linspace(min_angle, max_angle, endpoint = False, num=num_thetas)
R = Radon(theta=theta)

def get_data(batch_size, p, noise_lvl):
    p = cycle([p]) if isinstance(p, (int, float)) else cycle(p)
    
    x_recon = np.zeros((batch_size, 1, img_size, img_size))
    x = np.zeros((batch_size, 1, img_size, img_size))

    # set real images and inputs
    for i in range(batch_size):
        x[i,0,...] = rwn(p=next(p))
        sinogram =  R(x[i,0,...])
        sinogram += np.random.normal(0, noise_lvl, size=sinogram.shape)
        x_recon[i, 0, ...] = R.inverse(sinogram)

    return x_recon, torch.Tensor(x)

# %% [markdown]
# # Let's look at our Data!
# The below cell samples data from ```get_data```.

# %%
x_recon, x = get_data(5, float('inf'), 0.01)

fig, ax = plt.subplots(1,2, figsize = (10,8))
ax[1].imshow(x_recon[0,0,...])
ax[1].set_title('Naive Recon, input to the net')
ax[0].imshow(x.detach()[0,0,...])
ax[0].set_title('Original')
# Out:
# Text(0.5, 1.0, 'Original')

# %% [markdown]
# # Loading the model
#
# We now define the neural network model, we want to train in the following. Here, we use the celebrated UNet structure from this paper:
#
# <center>
# *Ronneberger, O., Fischer, P., & Brox, T. (2015). U-net: Convolutional networks for biomedical image segmentation. In Medical Image Computing and Computer-Assisted Intervention–MICCAI 2015: 18th International Conference, Munich, Germany, October 5-9, 2015, Proceedings, Part III 18 (pp. 234-241). Springer International Publishing.*
# </center>
#
#
# The model architecture is reimplemented (and slightly compressed) in the ```models``` module. We will now load the model and check how many parameters we will train in the following.
#
# **Spoiler**: Quite a lot.

# %%
from models import UNet
model = UNet()

model_parameters = filter(lambda p: p.requires_grad, model.parameters())
num_params = sum([np.prod(p.size()) for p in model_parameters])

print('Loaded the model with ' + str(num_params) + ' trainable parameters')
# Out:
# Loaded the model with 7696193 trainable parameters

# %% [markdown]
# # Training the model
# In order to train the model we consider the following minization problem:
#
# $$
# \min_\theta \mathbb{E}_{(x,y)}\left[ \ell(f_\theta(x), y)\right]$$
#
# where
#
# * $\theta$ denote the parameter of the neural network $f_\theta$,
# * $x$ is the noisy, badly recosntructed input,
# * $y$ is the clean ground truth image,
# * $\ell$ is the $L^2$ distance, i.e., $\ell(\hat y, y) = \|\hat y - y\|^2$.
#
# In order to solve can use stoachstic Gradient Descent, which yields the update
#
# $$\theta \gets \theta - \alpha \ \nabla_\theta \left(\sum_{i=1}^B \ell(f_\theta(x_i), y_i)\right).$$
#
# Here, $B$ denotes the batch size and $(x_1,y_1),\ldots, (x_B,y_B)$ are the outputs of ```get_data``` in each step. The parameter $\alpha$ denotes the step size.
#
# Alternatively, we employ the ADAM optimizer, which we define in the following cell. Additonally we define a learning rate scheduler.

# %%
import torch.nn as nn

loss_fct = nn.MSELoss()
opt = torch.optim.Adam(model.parameters(), lr=0.0005)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(opt, patience=30)

# %% [markdown]
# ## The train step
#
# We now define the train step, that updates the varaibels $\theta$.

# %%
def train_step(model, get_data, batch_size=5, p=2, noise_lvl=0.01):
    opt.zero_grad() # zero out gradients from previous step

    x_recon, x = get_data(batch_size, p, noise_lvl) # get data
    x_model = model(x_recon) # compute the model
    loss = loss_fct(x_model, x) # compute the loss
    loss.backward() # compute the gradients
    opt.step() # make a step of the optimizer
    scheduler.step(loss) # make a scheduler step

    # additonal computations and plotting
    loss1 = loss.item()
    loss2 = loss_fct(torch.Tensor(x_recon), torch.Tensor(x)).item()

    print(30*'-')
    print('Iteration: ' + str(num_it))
    print('Current Loss:' + str(loss1))
    print('IRadon Loss:' + str(loss2))
    for param_group in opt.param_groups:
        print('Current lr:' + str(param_group['lr']))

# %% [markdown]
# ### &#128221; <span style="color:darkorange"> Task 3.1 </span>
# #### Execute the training
#
# Your next task is to train the network. Please specify the following
#
# * ```train_shape```: the shape you train the network on
# * ```batch_size```: the batch size
# * ```max_it```: the maximal number of iteration step
# * ```noise_lvl```: the noise level
#
# Within your group you should choose different train shapes. After training you can evaluate your result with the cell below.

# %%
from tqdm.notebook import trange

train_p = [2]
batch_size = 5
max_it = 400
noise_lvl = 0.02

for num_it in trange(max_it):
    train_step(model, get_data, batch_size=batch_size, p=train_p, noise_lvl = noise_lvl)
# Out:
#   0%|          | 0/400 [00:00<?, ?it/s]
# ------------------------------
# Iteration: 0
# Current Loss:0.007903346791863441
# IRadon Loss:0.106977678835392
# Current lr:0.0005
# ------------------------------
# Iteration: 1
# Current Loss:0.049944303929805756
# IRadon Loss:0.12344495207071304
# Current lr:0.0005
# ------------------------------
# Iteration: 2
# Current Loss:0.01178905088454485
# IRadon Loss:0.10812409222126007
# Current lr:0.0005
# ------------------------------
# Iteration: 3
# Current Loss:0.007219681981950998
# IRadon Loss:0.10664548724889755
# Current lr:0.0005
# ------------------------------
# Iteration: 4
# Current Loss:0.017649490386247635
# IRadon Loss:0.11061421781778336
# Current lr:0.0005
# ------------------------------
# Iteration: 5
# Current Loss:0.01649976335465908
# IRadon Loss:0.12067294120788574
# Current lr:0.0005
# ------------------------------
# Iteration: 6
# Current Loss:0.00865999050438404
# IRadon Loss:0.11155210435390472
# Current lr:0.0005
# ------------------------------
# Iteration: 7
# Current Loss:0.010840605944395065
# IRadon Loss:0.11580084264278412
# Current lr:0.0005
# ------------------------------
# Iteration: 8
# Current Loss:0.01425065379589796
# IRadon Loss:0.12882600724697113
# Current lr:0.0005
# ------------------------------
# Iteration: 9
# Current Loss:0.01519657950848341
# IRadon Loss:0.1356140822172165
# Current lr:0.0005
# ------------------------------
# Iteration: 10
# Current Loss:0.008909481577575207
# IRadon Loss:0.11304950714111328
# Current lr:0.0005
# ------------------------------
# Iteration: 11
# Current Loss:0.010021713562309742
# IRadon Loss:0.1253511905670166
# Current lr:0.0005
# ------------------------------
# Iteration: 12
# Current Loss:0.007098334841430187
# IRadon Loss:0.11879780143499374
# Current lr:0.0005
# ------------------------------
# Iteration: 13
# Current Loss:0.005583839025348425
# IRadon Loss:0.11210058629512787
# Current lr:0.0005
# ------------------------------
# Iteration: 14
# Current Loss:0.006390013732016087
# IRadon Loss:0.1175939291715622
# Current lr:0.0005
# ------------------------------
# Iteration: 15
# Current Loss:0.0044326395727694035
# IRadon Loss:0.09662725776433945
# Current lr:0.0005
# ------------------------------
# Iteration: 16
# Current Loss:0.006488342769443989
# IRadon Loss:0.11268415302038193
# Current lr:0.0005
# ------------------------------
# Iteration: 17
# Current Loss:0.006570135243237019
# IRadon Loss:0.10734381526708603
# Current lr:0.0005
# ------------------------------
# Iteration: 18
# Current Loss:0.00601664325222373
# IRadon Loss:0.11005423218011856
# Current lr:0.0005
# ------------------------------
# Iteration: 19
# Current Loss:0.004358471371233463
# IRadon Loss:0.10796773433685303
# Current lr:0.0005
# ------------------------------
# Iteration: 20
# Current Loss:0.006930881645530462
# IRadon Loss:0.1327580362558365
# Current lr:0.0005
# ------------------------------
# Iteration: 21
# Current Loss:0.004388794302940369
# IRadon Loss:0.1166444793343544
# Current lr:0.0005
# ------------------------------
# Iteration: 22
# Current Loss:0.00412176176905632
# IRadon Loss:0.09808404743671417
# Current lr:0.0005
# ------------------------------
# Iteration: 23
# Current Loss:0.006951632909476757
# IRadon Loss:0.13470473885536194
# Current lr:0.0005
# ------------------------------
# Iteration: 24
# Current Loss:0.0063933455385267735
# IRadon Loss:0.12400688976049423
# Current lr:0.0005
# ------------------------------
# Iteration: 25
# Current Loss:0.005180001258850098
# IRadon Loss:0.10695133358240128
# Current lr:0.0005
# ------------------------------
# Iteration: 26
# Current Loss:0.005057675298303366
# IRadon Loss:0.10961268842220306
# Current lr:0.0005
# ------------------------------
# Iteration: 27
# Current Loss:0.006873613689094782
# IRadon Loss:0.13553300499916077
# Current lr:0.0005
# ------------------------------
# Iteration: 28
# Current Loss:0.00425714859738946
# IRadon Loss:0.11434318870306015
# Current lr:0.0005
# ------------------------------
# Iteration: 29
# Current Loss:0.0039002324920147657
# IRadon Loss:0.10776319354772568
# Current lr:0.0005
# ------------------------------
# Iteration: 30
# Current Loss:0.004609579686075449
# IRadon Loss:0.12392915785312653
# Current lr:0.0005
# ------------------------------
# Iteration: 31
# Current Loss:0.00389471766538918
# IRadon Loss:0.11517469584941864
# Current lr:0.0005
# ------------------------------
# Iteration: 32
# Current Loss:0.003888398874551058
# IRadon Loss:0.11380734294652939
# Current lr:0.0005
# ------------------------------
# Iteration: 33
# Current Loss:0.004535592161118984
# IRadon Loss:0.11426230520009995
# Current lr:0.0005
# ------------------------------
# Iteration: 34
# Current Loss:0.004309263080358505
# IRadon Loss:0.11730233579874039
# Current lr:0.0005
# ------------------------------
# Iteration: 35
# Current Loss:0.004573389887809753
# IRadon Loss:0.11764440685510635
# Current lr:0.0005
# ------------------------------
# Iteration: 36
# Current Loss:0.0038996729999780655
# IRadon Loss:0.12159085273742676
# Current lr:0.0005
# ------------------------------
# Iteration: 37
# Current Loss:0.004216683097183704
# IRadon Loss:0.11471731960773468
# Current lr:0.0005
# ------------------------------
# Iteration: 38
# Current Loss:0.0030878090765327215
# IRadon Loss:0.09408541768789291
# Current lr:0.0005
# ------------------------------
# Iteration: 39
# Current Loss:0.004295617341995239
# IRadon Loss:0.11692503839731216
# Current lr:0.0005
# ------------------------------
# Iteration: 40
# Current Loss:0.004839147441089153
# IRadon Loss:0.1267654150724411
# Current lr:0.0005
# ------------------------------
# Iteration: 41
# Current Loss:0.0028339852578938007
# IRadon Loss:0.10680688917636871
# Current lr:0.0005
# ------------------------------
# Iteration: 42
# Current Loss:0.002590961754322052
# IRadon Loss:0.0947100892663002
# Current lr:0.0005
# ------------------------------
# Iteration: 43
# Current Loss:0.003593920264393091
# IRadon Loss:0.11771953105926514
# Current lr:0.0005
# ------------------------------
# Iteration: 44
# Current Loss:0.003837738884612918
# IRadon Loss:0.12059208005666733
# Current lr:0.0005
# ------------------------------
# Iteration: 45
# Current Loss:0.0041092499159276485
# IRadon Loss:0.12453357875347137
# Current lr:0.0005
# ------------------------------
# Iteration: 46
# Current Loss:0.0031725838780403137
# IRadon Loss:0.10527421534061432
# Current lr:0.0005
# ------------------------------
# Iteration: 47
# Current Loss:0.003869313281029463
# IRadon Loss:0.12520167231559753
# Current lr:0.0005
# ------------------------------
# Iteration: 48
# Current Loss:0.0029574886430054903
# IRadon Loss:0.1186528205871582
# Current lr:0.0005
# ------------------------------
# Iteration: 49
# Current Loss:0.0035726174246519804
# IRadon Loss:0.12820106744766235
# Current lr:0.0005
# ------------------------------
# Iteration: 50
# Current Loss:0.002673229668289423
# IRadon Loss:0.1027781143784523
# Current lr:0.0005
# ------------------------------
# Iteration: 51
# Current Loss:0.0031169431749731302
# IRadon Loss:0.10404039919376373
# Current lr:0.0005
# ------------------------------
# Iteration: 52
# Current Loss:0.004793734289705753
# IRadon Loss:0.13785545527935028
# Current lr:0.0005
# ------------------------------
# Iteration: 53
# Current Loss:0.003840708639472723
# IRadon Loss:0.13981111347675323
# Current lr:0.0005
# ------------------------------
# Iteration: 54
# Current Loss:0.00414829608052969
# IRadon Loss:0.1332588493824005
# Current lr:0.0005
# ------------------------------
# Iteration: 55
# Current Loss:0.003394468454644084
# IRadon Loss:0.11279059946537018
# Current lr:0.0005
# ------------------------------
# Iteration: 56
# Current Loss:0.002783661475405097
# IRadon Loss:0.10732658207416534
# Current lr:0.0005
# ------------------------------
# Iteration: 57
# Current Loss:0.0031583397649228573
# IRadon Loss:0.12215141952037811
# Current lr:0.0005
# ------------------------------
# Iteration: 58
# Current Loss:0.0028746179305016994
# IRadon Loss:0.12003254890441895
# Current lr:0.0005
# ------------------------------
# Iteration: 59
# Current Loss:0.00306091271340847
# IRadon Loss:0.12525370717048645
# Current lr:0.0005
# ------------------------------
# Iteration: 60
# Current Loss:0.0027833175845444202
# IRadon Loss:0.11365876346826553
# Current lr:0.0005
# ------------------------------
# Iteration: 61
# Current Loss:0.003110911464318633
# IRadon Loss:0.11979401111602783
# Current lr:0.0005
# ------------------------------
# Iteration: 62
# Current Loss:0.0028653298504650593
# IRadon Loss:0.11150896549224854
# Current lr:0.0005
# ------------------------------
# Iteration: 63
# Current Loss:0.0028311791829764843
# IRadon Loss:0.11601603031158447
# Current lr:0.0005
# ------------------------------
# Iteration: 64
# Current Loss:0.002302661072462797
# IRadon Loss:0.10611383616924286
# Current lr:0.0005
# ------------------------------
# Iteration: 65
# Current Loss:0.0030686557292938232
# IRadon Loss:0.12446868419647217
# Current lr:0.0005
# ------------------------------
# Iteration: 66
# Current Loss:0.0030110289808362722
# IRadon Loss:0.1221519336104393
# Current lr:0.0005
# ------------------------------
# Iteration: 67
# Current Loss:0.0030178420711308718
# IRadon Loss:0.11360830068588257
# Current lr:0.0005
# ------------------------------
# Iteration: 68
# Current Loss:0.002392880152910948
# IRadon Loss:0.11928930133581161
# Current lr:0.0005
# ------------------------------
# Iteration: 69
# Current Loss:0.0028856100980192423
# IRadon Loss:0.11214347928762436
# Current lr:0.0005
# ------------------------------
# Iteration: 70
# Current Loss:0.002651005517691374
# IRadon Loss:0.11274228245019913
# Current lr:0.0005
# ------------------------------
# Iteration: 71
# Current Loss:0.0027647563256323338
# IRadon Loss:0.11087824404239655
# Current lr:0.0005
# ------------------------------
# Iteration: 72
# Current Loss:0.002225348027423024
# IRadon Loss:0.10036104917526245
# Current lr:0.0005
# ------------------------------
# Iteration: 73
# Current Loss:0.002650290494784713
# IRadon Loss:0.11287873983383179
# Current lr:0.0005
# ------------------------------
# Iteration: 74
# Current Loss:0.003249339060857892
# IRadon Loss:0.11832846701145172
# Current lr:0.0005
# ------------------------------
# Iteration: 75
# Current Loss:0.0023703621700406075
# IRadon Loss:0.11636736243963242
# Current lr:0.0005
# ------------------------------
# Iteration: 76
# Current Loss:0.001989210955798626
# IRadon Loss:0.10753390938043594
# Current lr:0.0005
# ------------------------------
# Iteration: 77
# Current Loss:0.002242718357592821
# IRadon Loss:0.0922638326883316
# Current lr:0.0005
# ------------------------------
# Iteration: 78
# Current Loss:0.002477432368323207
# IRadon Loss:0.11038698256015778
# Current lr:0.0005
# ------------------------------
# Iteration: 79
# Current Loss:0.0025385082699358463
# IRadon Loss:0.11895221471786499
# Current lr:0.0005
# ------------------------------
# Iteration: 80
# Current Loss:0.002120138145983219
# IRadon Loss:0.10104048252105713
# Current lr:0.0005
# ------------------------------
# Iteration: 81
# Current Loss:0.002671940950676799
# IRadon Loss:0.1204008013010025
# Current lr:0.0005
# ------------------------------
# Iteration: 82
# Current Loss:0.0025152070447802544
# IRadon Loss:0.11548390239477158
# Current lr:0.0005
# ------------------------------
# Iteration: 83
# Current Loss:0.0028673182241618633
# IRadon Loss:0.12339255958795547
# Current lr:0.0005
# ------------------------------
# Iteration: 84
# Current Loss:0.0024467413313686848
# IRadon Loss:0.11878818273544312
# Current lr:0.0005
# ------------------------------
# Iteration: 85
# Current Loss:0.002552399644628167
# IRadon Loss:0.10822205245494843
# Current lr:0.0005
# ------------------------------
# Iteration: 86
# Current Loss:0.0029061511158943176
# IRadon Loss:0.11275949329137802
# Current lr:0.0005
# ------------------------------
# Iteration: 87
# Current Loss:0.0024113922845572233
# IRadon Loss:0.10930545628070831
# Current lr:0.0005
# ------------------------------
# Iteration: 88
# Current Loss:0.003423647955060005
# IRadon Loss:0.115921750664711
# Current lr:0.0005
# ------------------------------
# Iteration: 89
# Current Loss:0.0024932106025516987
# IRadon Loss:0.11627411842346191
# Current lr:0.0005
# ------------------------------
# Iteration: 90
# Current Loss:0.0023918678052723408
# IRadon Loss:0.10744297504425049
# Current lr:0.0005
# ------------------------------
# Iteration: 91
# Current Loss:0.0029787723906338215
# IRadon Loss:0.12191351503133774
# Current lr:0.0005
# ------------------------------
# Iteration: 92
# Current Loss:0.0021365073043853045
# IRadon Loss:0.10323749482631683
# Current lr:0.0005
# ------------------------------
# Iteration: 93
# Current Loss:0.0015751601895317435
# IRadon Loss:0.09365807473659515
# Current lr:0.0005
# ------------------------------
# Iteration: 94
# Current Loss:0.002260513138025999
# IRadon Loss:0.11391720920801163
# Current lr:0.0005
# ------------------------------
# Iteration: 95
# Current Loss:0.002249076496809721
# IRadon Loss:0.10159339755773544
# Current lr:0.0005
# ------------------------------
# Iteration: 96
# Current Loss:0.002804627176374197
# IRadon Loss:0.13171984255313873
# Current lr:0.0005
# ------------------------------
# Iteration: 97
# Current Loss:0.0020713703706860542
# IRadon Loss:0.10586075484752655
# Current lr:0.0005
# ------------------------------
# Iteration: 98
# Current Loss:0.0023118932731449604
# IRadon Loss:0.11651426553726196
# Current lr:0.0005
# ------------------------------
# Iteration: 99
# Current Loss:0.0030881534330546856
# IRadon Loss:0.12280257046222687
# Current lr:0.0005
# ------------------------------
# Iteration: 100
# Current Loss:0.0018003920558840036
# IRadon Loss:0.1053345575928688
# Current lr:0.0005
# ------------------------------
# Iteration: 101
# Current Loss:0.002045848872512579
# IRadon Loss:0.10780975967645645
# Current lr:0.0005
# ------------------------------
# Iteration: 102
# Current Loss:0.0030857238452881575
# IRadon Loss:0.12671144306659698
# Current lr:0.0005
# ------------------------------
# Iteration: 103
# Current Loss:0.0023766569793224335
# IRadon Loss:0.13882651925086975
# Current lr:0.0005
# ------------------------------
# Iteration: 104
# Current Loss:0.002222646726295352
# IRadon Loss:0.10672305524349213
# Current lr:0.0005
# ------------------------------
# Iteration: 105
# Current Loss:0.002598646329715848
# IRadon Loss:0.1035805493593216
# Current lr:0.0005
# ------------------------------
# Iteration: 106
# Current Loss:0.0028045836370438337
# IRadon Loss:0.12034003436565399
# Current lr:0.0005
# ------------------------------
# Iteration: 107
# Current Loss:0.002143633086234331
# IRadon Loss:0.1105813980102539
# Current lr:0.0005
# ------------------------------
# Iteration: 108
# Current Loss:0.0028185187838971615
# IRadon Loss:0.11361962556838989
# Current lr:0.0005
# ------------------------------
# Iteration: 109
# Current Loss:0.0021682220976799726
# IRadon Loss:0.10028958320617676
# Current lr:0.0005
# ------------------------------
# Iteration: 110
# Current Loss:0.0029147141613066196
# IRadon Loss:0.12873445451259613
# Current lr:0.0005
# ------------------------------
# Iteration: 111
# Current Loss:0.001978896092623472
# IRadon Loss:0.11576906591653824
# Current lr:0.0005
# ------------------------------
# Iteration: 112
# Current Loss:0.0025434093549847603
# IRadon Loss:0.11219751834869385
# Current lr:0.0005
# ------------------------------
# Iteration: 113
# Current Loss:0.002509206999093294
# IRadon Loss:0.10435551404953003
# Current lr:0.0005
# ------------------------------
# Iteration: 114
# Current Loss:0.002304504159837961
# IRadon Loss:0.12475121021270752
# Current lr:0.0005
# ------------------------------
# Iteration: 115
# Current Loss:0.0020264459308236837
# IRadon Loss:0.11089926958084106
# Current lr:0.0005
# ------------------------------
# Iteration: 116
# Current Loss:0.0024062320590019226
# IRadon Loss:0.1183185800909996
# Current lr:0.0005
# ------------------------------
# Iteration: 117
# Current Loss:0.0027445643208920956
# IRadon Loss:0.12172003090381622
# Current lr:0.0005
# ------------------------------
# Iteration: 118
# Current Loss:0.0016236193478107452
# IRadon Loss:0.11989645659923553
# Current lr:0.0005
# ------------------------------
# Iteration: 119
# Current Loss:0.0018254835158586502
# IRadon Loss:0.1055317297577858
# Current lr:0.0005
# ------------------------------
# Iteration: 120
# Current Loss:0.0023403209634125233
# IRadon Loss:0.11770506203174591
# Current lr:0.0005
# ------------------------------
# Iteration: 121
# Current Loss:0.003119927365332842
# IRadon Loss:0.12912321090698242
# Current lr:0.0005
# ------------------------------
# Iteration: 122
# Current Loss:0.0018247654661536217
# IRadon Loss:0.11277852952480316
# Current lr:0.0005
# ------------------------------
# Iteration: 123
# Current Loss:0.0020976129453629255
# IRadon Loss:0.11518396437168121
# Current lr:0.0005
# ------------------------------
# Iteration: 124
# Current Loss:0.002702321158722043
# IRadon Loss:0.1281367987394333
# Current lr:5e-05
# ------------------------------
# Iteration: 125
# Current Loss:0.0021231891587376595
# IRadon Loss:0.11095980554819107
# Current lr:5e-05
# ------------------------------
# Iteration: 126
# Current Loss:0.002681237645447254
# IRadon Loss:0.12983720004558563
# Current lr:5e-05
# ------------------------------
# Iteration: 127
# Current Loss:0.0028009077068418264
# IRadon Loss:0.12900114059448242
# Current lr:5e-05
# ------------------------------
# Iteration: 128
# Current Loss:0.0021514755208045244
# IRadon Loss:0.11262686550617218
# Current lr:5e-05
# ------------------------------
# Iteration: 129
# Current Loss:0.0020205997861921787
# IRadon Loss:0.1139155849814415
# Current lr:5e-05
# ------------------------------
# Iteration: 130
# Current Loss:0.0022464266512542963
# IRadon Loss:0.12109849601984024
# Current lr:5e-05
# ------------------------------
# Iteration: 131
# Current Loss:0.0017546418821439147
# IRadon Loss:0.11223958432674408
# Current lr:5e-05
# ------------------------------
# Iteration: 132
# Current Loss:0.0017450284212827682
# IRadon Loss:0.1123710423707962
# Current lr:5e-05
# ------------------------------
# Iteration: 133
# Current Loss:0.0021848431788384914
# IRadon Loss:0.12359031289815903
# Current lr:5e-05
# ------------------------------
# Iteration: 134
# Current Loss:0.0019115150207653642
# IRadon Loss:0.11832550913095474
# Current lr:5e-05
# ------------------------------
# Iteration: 135
# Current Loss:0.001845679827965796
# IRadon Loss:0.10822145640850067
# Current lr:5e-05
# ------------------------------
# Iteration: 136
# Current Loss:0.002054340671747923
# IRadon Loss:0.11570491641759872
# Current lr:5e-05
# ------------------------------
# Iteration: 137
# Current Loss:0.0013052837457507849
# IRadon Loss:0.10132714360952377
# Current lr:5e-05
# ------------------------------
# Iteration: 138
# Current Loss:0.0020825881510972977
# IRadon Loss:0.1291055679321289
# Current lr:5e-05
# ------------------------------
# Iteration: 139
# Current Loss:0.00166823691688478
# IRadon Loss:0.10042402893304825
# Current lr:5e-05
# ------------------------------
# Iteration: 140
# Current Loss:0.0018517188727855682
# IRadon Loss:0.10791824012994766
# Current lr:5e-05
# ------------------------------
# Iteration: 141
# Current Loss:0.0036854639183729887
# IRadon Loss:0.14375156164169312
# Current lr:5e-05
# ------------------------------
# Iteration: 142
# Current Loss:0.001410301891155541
# IRadon Loss:0.08607765287160873
# Current lr:5e-05
# ------------------------------
# Iteration: 143
# Current Loss:0.0015453629894182086
# IRadon Loss:0.09834221750497818
# Current lr:5e-05
# ------------------------------
# Iteration: 144
# Current Loss:0.0017327923560515046
# IRadon Loss:0.11046457290649414
# Current lr:5e-05
# ------------------------------
# Iteration: 145
# Current Loss:0.001670641591772437
# IRadon Loss:0.1000843495130539
# Current lr:5e-05
# ------------------------------
# Iteration: 146
# Current Loss:0.0018285739934071898
# IRadon Loss:0.11275764554738998
# Current lr:5e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[77], line 9
#       6 noise_lvl = 0.02
#       8 for num_it in trange(max_it):
# ----> 9     train_step(model, get_data, batch_size=batch_size, p=train_p, noise_lvl = noise_lvl)
#
# Cell In[73], line 8, in train_step(model, get_data, batch_size, p, noise_lvl)
#       6 loss = loss_fct(x_model, x) # compute the loss
#       7 loss.backward() # compute the gradients
# ----> 8 opt.step() # make a step of the optimizer
#       9 scheduler.step(loss) # make a scheduler step
#      11 # additonal computations and plotting
#
# File ~\AppData\Local\miniconda3\envs\HI-school-2024\lib\site-packages\torch\optim\optimizer.py:484, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     479         else:
#     480             raise RuntimeError(
#     481                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     482             )
# --> 484 out = func(*args, **kwargs)
#     485 self._optimizer_step_code()
#     487 # call optimizer step post hooks
#
# File ~\AppData\Local\miniconda3\envs\HI-school-2024\lib\site-packages\torch\optim\optimizer.py:89, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      87     torch.set_grad_enabled(self.defaults["differentiable"])
#      88     torch._dynamo.graph_break()
# ---> 89     ret = func(self, *args, **kwargs)
#      90 finally:
#      91     torch._dynamo.graph_break()
#
# File ~\AppData\Local\miniconda3\envs\HI-school-2024\lib\site-packages\torch\optim\adam.py:226, in Adam.step(self, closure)
#     214     beta1, beta2 = group["betas"]
#     216     has_complex = self._init_group(
#     217         group,
#     218         params_with_grad,
#    (...)
#     223         state_steps,
#     224     )
# --> 226     adam(
#     227         params_with_grad,
#     228         grads,
#     229         exp_avgs,
#     230         exp_avg_sqs,
#     231         max_exp_avg_sqs,
#     232         state_steps,
#     233         amsgrad=group["amsgrad"],
#     234         has_complex=has_complex,
#     235         beta1=beta1,
#     236         beta2=beta2,
#     237         lr=group["lr"],
#     238         weight_decay=group["weight_decay"],
#     239         eps=group["eps"],
#     240         maximize=group["maximize"],
#     241         foreach=group["foreach"],
#     242         capturable=group["capturable"],
#     243         differentiable=group["differentiable"],
#     244         fused=group["fused"],
#     245         grad_scale=getattr(self, "grad_scale", None),
#     246         found_inf=getattr(self, "found_inf", None),
#     247     )
#     249 return loss
#
# File ~\AppData\Local\miniconda3\envs\HI-school-2024\lib\site-packages\torch\optim\optimizer.py:161, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     159     return disabled_func(*args, **kwargs)
#     160 else:
# --> 161     return func(*args, **kwargs)
#
# File ~\AppData\Local\miniconda3\envs\HI-school-2024\lib\site-packages\torch\optim\adam.py:766, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     763 else:
#     764     func = _single_tensor_adam
# --> 766 func(
#     767     params,
#     768     grads,
#     769     exp_avgs,
#     770     exp_avg_sqs,
#     771     max_exp_avg_sqs,
#     772     state_steps,
#     773     amsgrad=amsgrad,
#     774     has_complex=has_complex,
#     775     beta1=beta1,
#     776     beta2=beta2,
#     777     lr=lr,
#     778     weight_decay=weight_decay,
#     779     eps=eps,
#     780     maximize=maximize,
#     781     capturable=capturable,
#     782     differentiable=differentiable,
#     783     grad_scale=grad_scale,
#     784     found_inf=found_inf,
#     785 )
#
# File ~\AppData\Local\miniconda3\envs\HI-school-2024\lib\site-packages\torch\optim\adam.py:431, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     429         denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     430     else:
# --> 431         denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     433     param.addcdiv_(exp_avg, denom, value=-step_size)
#     435 # Lastly, switch back to complex view
#
# KeyboardInterrupt:

# %% [markdown]
# # Saving and loading the models
# If you want you can save or load models with the functions below.
#
# **BE CAREFUL NOT TO OVERWRITE PRECIOUS MODELS**

# %%
## save the model
save_model = True
if save_model:
    torch.save(model.state_dict(), train_shape + '.pt')

# %%
## load a model
load_model = True
if load_model:
    model.load_state_dict(torch.load('circle.pt'))

# %% [markdown]
# ### &#128221; <span style="color:darkorange"> Task 3.2 </span>
# #### Evaluating the results
#
# The cell below allows you to test the performance of your trained model.
#
# Yor task is to try out different shapes, noise levels and angle specification and evaluate the performance of your model :)

# %%
# %% Test
from utils import get_phantom
import ipywidgets as widgets
from ipywidgets import interactive
from IPython.display import display

img_size_test=64
im_kwargs = { 'vmin':0., 'vmax':1., 'cmap':'bone'}

def plot_result(logp, noise_lvl, angle):
    theta = np.linspace(angle[0],angle[1], endpoint = False, num=num_thetas)
    R = Radon(theta=theta)
    p = 2**logp if logp < 10 else float('inf')
    x = rwn(p=p)
    
    sinogram = R(x)
    sinogram += np.random.normal(0, noise_lvl, size=sinogram.shape)
    x_recon = R.inv(sinogram)
    x_model = model(x_recon).detach().numpy()[0,0,...]
    
    fig, ax = plt.subplots(1,3, figsize = (20,15))

    for i, (z, title) in enumerate([(x,'Ground truth'), (x_recon, 'Naive Recon'), (x_model,'Network Recon')]):  
        ax[i].imshow(z, **im_kwargs)
        ax[i].set_title(title + ', error: '+str(round(np.linalg.norm(x - z), 4)))
    ax[0].set_title('p=' +str(p))


p_slider = widgets.FloatSlider(min = 0.0, max = 10., step = 1, value = np.log(train_p)/np.log(2), continuous_update = False)
n_slider = widgets.FloatSlider(min = 0.0, max = .03, step = 0.001, value = 0.01, continuous_update = False)
a_slider = widgets.FloatRangeSlider(value=[0, 90],min=0,max=180,step=10,continuous_update=False)

interactive_plot = interactive(plot_result,logp = p_slider, angle=a_slider, noise_lvl=n_slider)
display(interactive_plot)
# Out:
# interactive(children=(FloatSlider(value=1.0, continuous_update=False, description='logp', max=10.0, step=1.0),…

# %% [markdown]
# # How can we combine model and data driven approaches?
#
# A popular way to combine model and data driven approaches are so-called plug-and-play (PnP) methods. The starting point is a variational minization problem
#
# $$\min_x \frac{1}{2}\, \|Ax - y\|^2 + \lambda J.$$
#
# These problem can be solved via prox-based methods, for example an ADMM update scheme
#
# $$
# \begin{align*}
# x &\gets \operatorname*{arg min}_{x}\ \frac{1}{2}\, \|Ax - y\|^2 + \frac{\rho}{2} \|{v - u}\|^2,\\
# v &\gets \operatorname*{arg min}_{v}\ \lambda J(v) + \frac{\rho}{2} \|{v - (x + u)}\|^2,\\
# u &\gets u + x - v.
# \end{align*}
# $$
#
# Here, the first line can be solved can be solved with a linear solver (e.g. the cg iteration) and the last line ist explicit. The second line is in fact the prox operator of $J$ since
#
# $$\operatorname{prox}_{\lambda/\rho\ J}(x+u) =  \operatorname*{arg min}_{v}\ \lambda J(v) + \frac{\rho}{2} \|{v - (x + u)}\|^2.$$
#
# Evaluating this prox can be complicated and relies on a possibly hand-crafted functional $J$. The idea of PnP methods consists of replacing a prox step of this kind by an arbitratry map $D$. I.e. the iteration takes the form
#
# $$
# \begin{align*}
# x &\gets \operatorname*{arg min}_{x}\ \frac{1}{2}\, \|Ax - y\|^2 + \frac{\rho}{2} \|{v - u}\|^2,\\
# v &\gets D_\lambda(x + u),\\
# u &\gets u + x - v.
# \end{align*}
# $$
#
# Typically this function $D$ is a simple denoiser, i.e., a mapping that takes a noisy images and outputs a clear version.
#
# ## Training the denoiser
#
# We want to try out the PnP approaches from above. To do so we first train a denoiser $D$. Here, we use the same setup as before, we just have to change the ```get_data``` function.

# %%
def get_data(batch_size, train_shape, noise_lvl):
    x_recon = np.zeros((batch_size, 1, img_size, img_size))
    x = np.zeros((batch_size, 1, img_size, img_size))

    # set real images and inputs
    for i in range(batch_size):
        x[i,0,...] = rwn(train_p)
        x_recon[i, 0, ...] = x[i,0,...] + np.random.normal(0, noise_lvl, size=x[i,0,...].shape)
    return x_recon, torch.Tensor(x)

# %% [markdown]
# ## Look at the data again
#
# The data looks slightly different now.

# %%
x_recon, x = get_data(5, float('inf'), 0.02)

fig, ax = plt.subplots(1,2, figsize = (10,8))
ax[1].imshow(x_recon[0,0,...])
ax[1].set_title('Naive Recon')
ax[0].imshow(x.detach()[0,0,...])
ax[0].set_title('Original')
# Out:
# Text(0.5, 1.0, 'Original')

# %% [markdown]
# ### &#128221; <span style="color:darkorange"> Task 3.3 </span>
# #### Train again
#
# With the same set up as before you can now train the denoising model.

# %%
denoiser = UNet()
opt = torch.optim.Adam(denoiser.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=10, eta_min=0)

# %%
train_shape = 'random'
batch_size = 5
max_it = 50

for num_it in range(max_it):
    train_step(denoiser, get_data, batch_size=batch_size, train_shape=train_shape)
# Out:
# ------------------------------
# Iteration: 0
# Current Loss:0.07639087736606598
# IRadon Loss:9.879553545033559e-05
# Current lr:0.0009755282581475768
# ------------------------------
# Iteration: 1
# Current Loss:0.09227783232927322
# IRadon Loss:9.999066969612613e-05
# Current lr:0.0009045084971874736
# ------------------------------
# Iteration: 2
# Current Loss:0.05828582122921944
# IRadon Loss:0.0001021273055812344
# Current lr:0.0007938926261462366
# ------------------------------
# Iteration: 3
# Current Loss:0.11030822992324829
# IRadon Loss:9.89128602668643e-05
# Current lr:0.0006545084971874737
# ------------------------------
# Iteration: 4
# Current Loss:0.027378495782613754
# IRadon Loss:0.00010059168562293053
# Current lr:0.0005
# ------------------------------
# Iteration: 5
# Current Loss:0.032982856035232544
# IRadon Loss:0.00010109068534802645
# Current lr:0.00034549150281252633
# ------------------------------
# Iteration: 6
# Current Loss:0.022400658577680588
# IRadon Loss:9.968989616027102e-05
# Current lr:0.0002061073738537635
# ------------------------------
# Iteration: 7
# Current Loss:0.025853285565972328
# IRadon Loss:9.83990466920659e-05
# Current lr:9.549150281252634e-05
# ------------------------------
# Iteration: 8
# Current Loss:0.020915891975164413
# IRadon Loss:0.00010121407831320539
# Current lr:2.4471741852423235e-05
# ------------------------------
# Iteration: 9
# Current Loss:0.020190076902508736
# IRadon Loss:9.884448809316382e-05
# Current lr:0.0
# ------------------------------
# Iteration: 10
# Current Loss:0.023803003132343292
# IRadon Loss:9.887557098409161e-05
# Current lr:2.4471741852423235e-05
# ------------------------------
# Iteration: 11
# Current Loss:0.013659687712788582
# IRadon Loss:0.00010013714199885726
# Current lr:9.54915028125267e-05
# ------------------------------
# Iteration: 12
# Current Loss:0.02104388177394867
# IRadon Loss:0.00010037054016720504
# Current lr:0.0002061073738537643
# ------------------------------
# Iteration: 13
# Current Loss:0.012273375876247883
# IRadon Loss:9.938331641023979e-05
# Current lr:0.0003454915028125278
# ------------------------------
# Iteration: 14
# Current Loss:0.014583984389901161
# IRadon Loss:9.96229937300086e-05
# Current lr:0.0005000000000000022
# ------------------------------
# Iteration: 15
# Current Loss:0.008471041917800903
# IRadon Loss:0.00010031578131020069
# Current lr:0.0006545084971874766
# ------------------------------
# Iteration: 16
# Current Loss:0.00919160433113575
# IRadon Loss:0.00010074805322801694
# Current lr:0.00079389262614624
# ------------------------------
# Iteration: 17
# Current Loss:0.023347578942775726
# IRadon Loss:9.852564107859507e-05
# Current lr:0.0009045084971874779
# ------------------------------
# Iteration: 18
# Current Loss:0.0325794592499733
# IRadon Loss:0.00010122529783984646
# Current lr:0.0009755282581475812
# ------------------------------
# Iteration: 19
# Current Loss:0.018041018396615982
# IRadon Loss:9.950842650141567e-05
# Current lr:0.0010000000000000046
# ------------------------------
# Iteration: 20
# Current Loss:0.006610587239265442
# IRadon Loss:0.00010007794480770826
# Current lr:0.0009755282581475812
# ------------------------------
# Iteration: 21
# Current Loss:0.012048541568219662
# IRadon Loss:9.776842489372939e-05
# Current lr:0.0009045084971874781
# ------------------------------
# Iteration: 22
# Current Loss:0.014297318644821644
# IRadon Loss:9.909555956255645e-05
# Current lr:0.0007938926261462403
# ------------------------------
# Iteration: 23
# Current Loss:0.025318298488855362
# IRadon Loss:0.00010164859850192443
# Current lr:0.0006545084971874768
# ------------------------------
# Iteration: 24
# Current Loss:0.01569177955389023
# IRadon Loss:0.00010082412336487323
# Current lr:0.0005000000000000024
# ------------------------------
# Iteration: 25
# Current Loss:0.01382660586386919
# IRadon Loss:9.92109053186141e-05
# Current lr:0.00034549150281252807
# ------------------------------
# Iteration: 26
# Current Loss:0.011478065513074398
# IRadon Loss:0.0001005739759420976
# Current lr:0.00020610737385376454
# ------------------------------
# Iteration: 27
# Current Loss:0.006586265750229359
# IRadon Loss:0.00010145318083232269
# Current lr:9.549150281252684e-05
# ------------------------------
# Iteration: 28
# Current Loss:0.006035464815795422
# IRadon Loss:9.930251690093428e-05
# Current lr:2.4471741852423408e-05
# ------------------------------
# Iteration: 29
# Current Loss:0.00785789918154478
# IRadon Loss:9.910928929457441e-05
# Current lr:0.0
# ------------------------------
# Iteration: 30
# Current Loss:0.007731769233942032
# IRadon Loss:9.791953198146075e-05
# Current lr:2.4471741852423235e-05
# ------------------------------
# Iteration: 31
# Current Loss:0.008192593231797218
# IRadon Loss:0.00010071556607726961
# Current lr:9.549150281252638e-05
# ------------------------------
# Iteration: 32
# Current Loss:0.005792857613414526
# IRadon Loss:0.00010140449739992619
# Current lr:0.00020610737385376373
# ------------------------------
# Iteration: 33
# Current Loss:0.007158016320317984
# IRadon Loss:9.986499935621396e-05
# Current lr:0.0003454915028125268
# ------------------------------
# Iteration: 34
# Current Loss:0.0066216811537742615
# IRadon Loss:0.00010101275984197855
# Current lr:0.0005000000000000009
# ------------------------------
# Iteration: 35
# Current Loss:0.007048498839139938
# IRadon Loss:9.925945050781593e-05
# Current lr:0.0006545084971874749
# ------------------------------
# Iteration: 36
# Current Loss:0.006239151116460562
# IRadon Loss:0.00010017333261203021
# Current lr:0.0007938926261462382
# ------------------------------
# Iteration: 37
# Current Loss:0.006592083722352982
# IRadon Loss:9.993878484237939e-05
# Current lr:0.0009045084971874756
# ------------------------------
# Iteration: 38
# Current Loss:0.008364669978618622
# IRadon Loss:9.951930405804887e-05
# Current lr:0.000975528258147579
# ------------------------------
# Iteration: 39
# Current Loss:0.008243327960371971
# IRadon Loss:9.871004294836894e-05
# Current lr:0.0010000000000000024
# ------------------------------
# Iteration: 40
# Current Loss:0.00597684970125556
# IRadon Loss:9.963153570424765e-05
# Current lr:0.0009755282581475795
# ------------------------------
# Iteration: 41
# Current Loss:0.005496134050190449
# IRadon Loss:9.951229731086642e-05
# Current lr:0.0009045084971874761
# ------------------------------
# Iteration: 42
# Current Loss:0.0059583489783108234
# IRadon Loss:0.00010048345575341955
# Current lr:0.0007938926261462387
# ------------------------------
# Iteration: 43
# Current Loss:0.006954375654459
# IRadon Loss:9.820116974879056e-05
# Current lr:0.0006545084971874765
# ------------------------------
# Iteration: 44
# Current Loss:0.00427404697984457
# IRadon Loss:0.00010007697710534558
# Current lr:0.0005000000000000014
# ------------------------------
# Iteration: 45
# Current Loss:0.004733824171125889
# IRadon Loss:9.986098302761093e-05
# Current lr:0.00034549150281252736
# ------------------------------
# Iteration: 46
# Current Loss:0.005241463892161846
# IRadon Loss:9.962681360775605e-05
# Current lr:0.00020610737385376343
# ------------------------------
# Iteration: 47
# Current Loss:0.004739926662296057
# IRadon Loss:0.00010123561514774337
# Current lr:9.549150281252668e-05
# ------------------------------
# Iteration: 48
# Current Loss:0.004263858310878277
# IRadon Loss:0.00010055852180812508
# Current lr:2.447174185242363e-05
# ------------------------------
# Iteration: 49
# Current Loss:0.005274441093206406
# IRadon Loss:9.896214032778516e-05
# Current lr:0.0

# %% [markdown]
# # How well does it work?
# The cell below shows the denoising performance of the trained network.

# %%
x_recon, x = get_data(5, 'random', 0.05)

fig, ax = plt.subplots(1,3)
ax[2].imshow(denoiser(x_recon).detach()[0,0,...])
ax[2].set_title('Model Recon')
ax[1].imshow(x_recon[0,0,...])
ax[1].set_title('Naive Recon')
ax[0].imshow(x.detach()[0,0,...])
ax[0].set_title('Original')
# Out:
# Text(0.5, 1.0, 'Original')

# %% [markdown]
# ## Defining the PnP prox substitute
#
# Our original goal was to substitute the prox in the admm itertion. In the module ```optimizer``` the optimizer ```admm``` is defined. It has the following signature for initialization:
#
# ```admm(R, x0, Rx, rho=0.4, lamda=1., verbosity=0, prox=model_prox, max_it=35, max_inner_it=1)```
#
# where
#
# * ```R``` is the linear operator, i.e. the Radon trafo
# * ```x0``` is the inital guess
# * ```rho``` is an iteration parameter
# * ```lamda``` scales the influence of the prox
# * ```prox``` defines the prox mapping
# * ```max_it``` determines the umber of steps
# * ```max_inner_it``` determines the number of inner iterations
#
# We just have to define the prox maping

# %%
def model_prox(x, lamda):
    lamda = max(min(lamda, 1.),0)
    return (1-lamda) * x + lamda * denoiser(x).detach().numpy()[0,0,...]

# %% [markdown]
# ### &#128221; <span style="color:darkorange"> Task 3.4 </span>
# #### Test the performance on the CT problem
#
# With the following cell you can now test how well the denoiser and the PnP-ADMM iteration performs on the CT reconstruction task. How does the noise level influence the performance?

# %%
from optimizers import admm

num_thetas = 30
min_angle = 0
max_angle = 180
theta = np.linspace(min_angle, max_angle, endpoint = False, num=num_thetas)
R = Radon(theta=theta)

def plot_recon(noise_lvl):
    x_recon, x = get_data(5, 'random', 0.01)
    Rx = R(x[0,0,...])
    Rx += np.random.normal(0, noise_lvl, size=Rx.shape)
    x0 = R.inv(Rx)
    sinogram = R(x0)
    
    pnpadmm = admm(R, 0*x0, Rx, rho=0.4, lamda=1., verbosity=0, prox=model_prox, max_it=35, max_inner_it=1)
    pnpadmm.solve()
    
    x = x[0,0,...].numpy()
    x_model = denoiser(x0).detach().numpy()[0,0,...]
    fig, ax = plt.subplots(1,4, figsize=(20,15))
    ax[0].imshow(x)
    ax[0].set_title('original')
    ax[2].imshow(pnpadmm.x)
    ax[2].set_title('PnP ADMM Recon, error: ' + str(np.linalg.norm(pnpadmm.x - x)))
    ax[1].imshow(x_model)
    ax[1].set_title('Network Recon, error: ' + str(np.linalg.norm(x_model - x)))
    ax[3].imshow(x0)
    ax[3].set_title('Naive Recon')



n_slider = widgets.FloatSlider(min = 0.0, max = .1, step = 0.001, value = 0.01, continuous_update = False)
interactive_plot = interactive(plot_recon, noise_lvl=n_slider)
display(interactive_plot)
# Out:
# interactive(children=(FloatSlider(value=0.01, continuous_update=False, description='noise_lvl', max=0.1, step=…

# %% [markdown]
# ## Saving the Denoiser
# If you want you can save or load a denoiser, but as before
#
# **CAUTION!**

# %%
## save the model
save_model = False
if save_model:
    torch.save(denoiser.state_dict(), 'denoiser.pt')

# %%
## load a model
load_model = True
if load_model:
    denoiser.load_state_dict(torch.load('denoiser.pt'))
